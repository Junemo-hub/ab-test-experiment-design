# %% [markdown]
# # 📘 Final Report: A/B Test Analysis
#
# ---
#
#
# 🧾 Supplementary Document for Master's Application
#
# I submitted this report to accompany my early application, leveraging the early deadline to demonstrate both my preparedness and sustained commitment to growth in data science.
#
# While I’ve worked with applied machine learning using tools like scikit-learn, I took this opportunity to revisit core concepts in A/B testing and statistics. The project helped me solidify essential topics like hypothesis testing, confidence intervals, and practical experiment design—skills that are highly relevant in real-world data science work.
#
# This project reflects my ongoing commitment to developing both the technical and analytical mindset needed to succeed in a professional data science environment.
#
# > 💻 Code available on [GitHub](https://github.com/Junemo-hub/ab-test-experiment-design/tree/main/01_abtest_ecommerce_2022)
#
# ## 1. Experiment Overview
#
# - **Objective:** To evaluate whether the new landing page leads to a higher conversion rate compared to the old one.
# - **Group Allocation:**
#   Control: Old landing page
#   Treatment: New landing page
#
# ---
#
# ## 2. 📊 Summary of Experimental Data
#
# | Group      | Conversions | Total Users | Conversion Rate (%) |
# |------------|-------------|-------------|----------------------|
# | Control    | 17,489      | 145,274     | 12.04%               |
# | Treatment  | 17,264      | 145,315     | 11.89%               |
#
# > Dataset: [Kaggle - Ecommerce A/B Testing (2022)](https://www.kaggle.com/datasets/putdejudomthai/ecommerce-ab-testing-2022-dataset1/data)
#
# ---
#
# ## 3. 🔬 Statistical Analysis
#
# - **Z-Test (Proportion Test):**
#   - Z-statistic: `1.3143`
#   - P-value: `0.1887`
#   - ❌ No statistically significant difference at α = 0.05
#
# - **Chi-Square Test:**
#   - χ²-statistic: `1.7125`
#   - P-value: `0.1907`
#
# - **Effect Size (Cohen's h):** `0.0049`
#   - 🟡 Very small effect (less than 0.2)
#
# - **95% Confidence Intervals for Conversion Rates:**
#   - Control: [0.1187, 0.1221]
#   - Treatment: [0.1171, 0.1205]
#   → Overlapping confidence intervals indicate **no significant difference** in conversion rates between the groups.
#
# ---
#
# ## 4. Visualizations
#
# ### ✅ Conversion Rate by Group
# <img src="../outputs/figures/1_group_conversion.png" width="300"/>
#
# ### ✅ Conversion Rate by Country and Group
# <img src="../outputs/figures/2_country_group_conv.png" width="300"/>
#
# <br>
# <br>
#
# ### ✅ Z-Test Result Visualization
# <img src="../outputs/figures/3_conversion_rate_comparison.png" width="300"/>
#
# ---
#
# ## 5. Conclusion & Insights
#
# - ✅ The control group showed a slightly higher conversion rate (12.04%) than the treatment group (11.89%).
# - ❌ However, since the **p-value is 0.1887**, there is **no statistically significant difference** between the two groups.
# - 🎯 **Conclusion:** The new landing page does not show a clear performance improvement over the old one.
# → It is recommended to **continue using the current page for now**.
#
# ---
#
# ## 6. 📌 Recommendations
#
# - Run follow-up experiments including additional KPIs such as time on page or scroll depth.
# - Consider subgroup A/B testing by country or device type to detect regional effects.
# - Experiment with other UX/UI elements (e.g., CTA wording, product recommendations) to potentially improve conversion.
